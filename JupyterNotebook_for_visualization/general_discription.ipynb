# %%
#%% import pakages
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

# %%
#  set parameters

# import function
function_dir_ = 'C:/Users/daizh/manuscript_shear_structure_formation_different_conditions/python_file'
os.chdir(function_dir_)
from import_data import *

#  work path
wd_ = 'D:/sheared_granular_gouge_different_evironment_condition'
#%% change current directory
os.chdir(wd_)

# set data path
path_FrictionState_ = 'particle_info/particle_info_friction_state.txt'
path_ParticleInfo_ = 'particle_info/particle_info_%d.txt' # note this path need to replace the number
path_HistoryData_ = 'particle_info/history_data.his'

path_NormalStress_ = ['1MPa', '10MPa', '20MPa', '30MPa', '40MPa']
path_ShearVelocity_ = ['p01mps', 'p05mps', 'p1mps', 'p5mps', '1mps']
path_LoadStiffness_ = ['1k', '2k', '4k', '20k', '80k']

path_Conditions_ = ['normal_stress', 'shear_velocity', 'k']

# %%
#%% read FrictionState and HistoryData (normal stress)
# table head: 0. Load pointer displacement, 1. Friction, 2. Top plate displacement, 
# 3. Bottom plate displacement, 4. Top plate velocity, 5. Bottom plate velocity
FrictionState_1MPa_ = read_FrictionState(os.path.join(path_Conditions_[0], path_NormalStress_[0], path_FrictionState_))
FrictionState_10MPa_ = read_FrictionState(os.path.join(path_Conditions_[0], path_NormalStress_[1], path_FrictionState_))
FrictionState_20MPa_ = read_FrictionState(os.path.join(path_Conditions_[0], path_NormalStress_[2], path_FrictionState_))
FrictionState_30MPa_ = read_FrictionState(os.path.join(path_Conditions_[0], path_NormalStress_[3], path_FrictionState_))
FrictionState_40MPa_ = read_FrictionState(os.path.join(path_Conditions_[0], path_NormalStress_[4], path_FrictionState_))

# table head: 0. step, 1. displacement, 2. gouge_thickness, 3. shear_strain,
# 4. shear_stress, 5. normal_stress, 6. friction,  7. plate_displacement,
# 8. plate_velocity, 9. plate_displacement_bottom, 10. plate_velocity_bottom,
# 11. shear_strain_rate
HistoryData_1MPa_ = read_HistoryData(os.path.join(path_Conditions_[0], path_NormalStress_[0], path_HistoryData_))
HistoryData_10MPa_ = read_HistoryData(os.path.join(path_Conditions_[0], path_NormalStress_[1], path_HistoryData_))
HistoryData_20MPa_ = read_HistoryData(os.path.join(path_Conditions_[0], path_NormalStress_[2], path_HistoryData_))
HistoryData_30MPa_ = read_HistoryData(os.path.join(path_Conditions_[0], path_NormalStress_[3], path_HistoryData_))
HistoryData_40MPa_ = read_HistoryData(os.path.join(path_Conditions_[0], path_NormalStress_[4], path_HistoryData_))
# Out:
# Reading friction state...
#
# Index(['Load pointer displacement', ' Friction', ' Top plate displacement',
#        ' Bottom plate displacement', ' Top plate velocity',
#        ' Bottom plate velocity'],
#       dtype='object')
#
# Read friction state successful
#
#
# Reading friction state...
#
# Index(['Load pointer displacement', ' Friction', ' Top plate displacement',
#        ' Bottom plate displacement', ' Top plate velocity',
#        ' Bottom plate velocity'],
#       dtype='object')
#
# Read friction state successful
#
#
# Reading friction state...
#
# Index(['Load pointer displacement', ' Friction', ' Top plate displacement',
#        ' Bottom plate displacement', ' Top plate velocity',
#        ' Bottom plate velocity'],
#       dtype='object')
#
# Read friction state successful
#
#
# Reading friction state...
#
# Index(['Load pointer displacement', ' Friction', ' Top plate displacement',
#        ' Bottom plate displacement', ' Top plate velocity',
# ...

# %%
# friction overall (different normal stress)
plt.figure(figsize=(2.6,2.4))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.plot(HistoryData_1MPa_[:, 1] * 1000,  \
         HistoryData_1MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'g', label = '1 MPa')
plt.plot(HistoryData_10MPa_[:, 1] * 1000,  \
         HistoryData_10MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'b', label = '10 MPa')
plt.plot(HistoryData_20MPa_[:, 1] * 1000,  \
         HistoryData_20MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'darkorange', label = '20 MPa')
plt.plot(HistoryData_30MPa_[:, 1] * 1000,  \
         HistoryData_30MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'm', label = '30 MPa')
plt.plot(HistoryData_40MPa_[:, 1] * 1000,  \
         HistoryData_40MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'k', label = '40 MPa')

plt.xlim([-0.1, 4])
plt.ylim([-0.5, 15])
plt.xlabel('Displacement (mm)', fontsize = 10)
plt.ylabel('Shear stress (MPa)', fontsize = 10)
# plt.legend(frameon=False)
plt.tight_layout()
plt.savefig('C:/Users/daizh/manuscript_shear_structure_formation_different_conditions/python_file/notebook_plot/general_discription_normal_stress.svg', dpi=600, format='svg')
plt.show()

# %%
fig = plt.figure(figsize=(2.4,2.4*3))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

# set height ratios for subplots
# set layout
gs = gridspec.GridSpec(3, 1, height_ratios=[1, 1, 1]) 
ax2 = plt.subplot(gs[2])
ax2s=ax2.twinx()  
ax1 = plt.subplot(gs[1], sharex = ax2)
ax1s=ax1.twinx()  
ax0 = plt.subplot(gs[0], sharex = ax2)
ax0s=ax0.twinx()  
ax0.label_outer()
ax1.label_outer()
plt.subplots_adjust(hspace=.0)
# set color
ax0s.spines['right'].set_color('r')
ax0s.tick_params(axis='y', colors='red')
ax1s.spines['right'].set_color('r')
ax1s.tick_params(axis='y', colors='red')
ax2s.spines['right'].set_color('r')
ax2s.tick_params(axis='y', colors='red')
# plot respectively
ax0.plot(HistoryData_40MPa_[:, 1] * 1000,  \
         HistoryData_40MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'k', )
ax0.set_xlim([3.3, 3.6])
ax0.set_xticks([3.3, 3.4, 3.5, 3.6])
ax0.set_ylim(9.5, 11.5)
ax0.set_yticks([10.0, 10.5, 11.0, 11.5])
ax1.plot(HistoryData_20MPa_[:, 1] * 1000,  \
         HistoryData_20MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'darkorange', )
ax1.set_ylim(4.0, 6.5)
ax1.set_yticks([4.5, 5.0, 5.5, 6.0])
ax2.plot(HistoryData_1MPa_[:, 1] * 1000,  \
         HistoryData_1MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'g', )
ax2.set_ylim(0.2, 0.4)
ax2.set_yticks([0.25, 0.30, 0.35])

ax0s.plot(HistoryData_40MPa_[:, 1] * 1000,  \
         np.abs((HistoryData_40MPa_[:, 8] - HistoryData_40MPa_[:, 10]) / 2),\
         linewidth = 1, color = 'r', )
ax0s.set_ylim(-0.5, 2.5)
ax0s.set_yticks([0, 0.5, 1.0, 1.5, 2, 2.5])
ax1s.plot(HistoryData_20MPa_[:, 1] * 1000,  \
         np.abs((HistoryData_20MPa_[:, 8] - HistoryData_20MPa_[:, 10]) / 2),\
         linewidth = 1, color = 'r', )
ax1s.set_ylim(-0.5, 2.5)
ax1s.set_yticks([0, 0.5, 1.0, 1.5, 2, 2.5])
ax2s.plot(HistoryData_1MPa_[:, 1] * 1000,  \
         np.abs((HistoryData_1MPa_[:, 8] - HistoryData_1MPa_[:, 10]) / 2),\
         linewidth = 1, color = 'r', )
ax2s.set_ylim(-0.5, 2.5)
ax2s.set_yticks([0, 0.5, 1.0, 1.5, 2, 2.5])
# set labels
ax2.set_xlabel('Displacement (mm)', fontsize = 10)
ax0.set_ylabel('Shear stress (MPa)', fontsize = 10)
ax1.set_ylabel('Shear stress (MPa)', fontsize = 10)
ax2.set_ylabel('Shear stress (MPa)', fontsize = 10)
ax0s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax1s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax2s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax0.get_xaxis().set_visible(False)
ax1.get_xaxis().set_visible(False)
ax0.spines['bottom'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax0s.spines['bottom'].set_visible(False)
ax1s.spines['top'].set_visible(False)
ax1s.spines['bottom'].set_visible(False)
ax2s.spines['top'].set_visible(False)

#  save figure

plt.savefig('C:/Users/daizh/manuscript_shear_structure_formation_different_conditions/python_file/notebook_plot/general_discription_normal_stress_inset.svg', dpi=600, format='svg')
plt.show()

# %%
#%% read FrictionState and HistoryData (shear velocity)
# table head: 0. Load pointer displacement, 1. Friction, 2. Top plate displacement, 
# 3. Bottom plate displacement, 4. Top plate velocity, 5. Bottom plate velocity
FrictionState_p01mps_ = read_FrictionState(os.path.join(path_Conditions_[1], path_ShearVelocity_[0], path_FrictionState_))
FrictionState_p05mps_ = read_FrictionState(os.path.join(path_Conditions_[1], path_ShearVelocity_[1], path_FrictionState_))
FrictionState_p1mps_ = read_FrictionState(os.path.join(path_Conditions_[1], path_ShearVelocity_[2], path_FrictionState_))
FrictionState_p5mps_ = read_FrictionState(os.path.join(path_Conditions_[1], path_ShearVelocity_[3], path_FrictionState_))
FrictionState_1mps_ = read_FrictionState(os.path.join(path_Conditions_[1], path_ShearVelocity_[4], path_FrictionState_))

# table head: 0. step, 1. displacement, 2. gouge_thickness, 3. shear_strain,
# 4. shear_stress, 5. normal_stress, 6. friction,  7. plate_displacement,
# 8. plate_velocity, 9. plate_displacement_bottom, 10. plate_velocity_bottom,
# 11. shear_strain_rate
HistoryData_p01mps_ = read_HistoryData(os.path.join(path_Conditions_[1], path_ShearVelocity_[0], path_HistoryData_))
HistoryData_p05mps_ = read_HistoryData(os.path.join(path_Conditions_[1], path_ShearVelocity_[1], path_HistoryData_))
HistoryData_p1mps_ = read_HistoryData(os.path.join(path_Conditions_[1], path_ShearVelocity_[2], path_HistoryData_))
HistoryData_p5mps_ = read_HistoryData(os.path.join(path_Conditions_[1], path_ShearVelocity_[3], path_HistoryData_))
HistoryData_1mps_ = read_HistoryData(os.path.join(path_Conditions_[1], path_ShearVelocity_[4], path_HistoryData_))
# Out:
# Reading friction state...
#
# Index(['Load pointer displacement', ' Friction', ' Top plate displacement',
#        ' Bottom plate displacement', ' Top plate velocity',
#        ' Bottom plate velocity'],
#       dtype='object')
#
# Read friction state successful
#
#
# Reading friction state...
#
# Index(['Load pointer displacement', ' Friction', ' Top plate displacement',
#        ' Bottom plate displacement', ' Top plate velocity',
#        ' Bottom plate velocity'],
#       dtype='object')
#
# Read friction state successful
#
#
# Reading friction state...
#
# Index(['Load pointer displacement', ' Friction', ' Top plate displacement',
#        ' Bottom plate displacement', ' Top plate velocity',
#        ' Bottom plate velocity'],
#       dtype='object')
#
# Read friction state successful
#
#
# Reading friction state...
#
# Index(['Load pointer displacement', ' Friction', ' Top plate displacement',
#        ' Bottom plate displacement', ' Top plate velocity',
# ...

# %%
# friction overall (different shear velocity)
plt.figure(figsize=(2.4,2.4))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

plt.plot(HistoryData_p01mps_[:, 1] * 1000,  \
         HistoryData_p01mps_[:, 4]/10**6,\
         linewidth = 1, color = 'g', label = '0.01 m/s')
plt.plot(HistoryData_p05mps_[:, 1] * 1000,  \
         HistoryData_p05mps_[:, 4]/10**6,\
         linewidth = 1, color = 'b', label = '0.05 m/s')
plt.plot(HistoryData_p1mps_[:, 1] * 1000,  \
         HistoryData_p1mps_[:, 4]/10**6,\
         linewidth = 1, color = 'darkorange', label = '0.1 m/s')
plt.plot(HistoryData_p5mps_[:, 1] * 1000,  \
         HistoryData_p5mps_[:, 4]/10**6,\
         linewidth = 1, color = 'm', label = '0.5 m/s')
plt.plot(HistoryData_1mps_[:, 1] * 1000,  \
         HistoryData_1mps_[:, 4]/10**6,\
         linewidth = 1, color = 'k', label = '1 m/s')

plt.xlim([-0.1, 4])
plt.ylim([0, 7])
plt.yticks([0, 1, 2, 3, 4, 5, 6, 7])
plt.xlabel('Displacement (mm)', fontsize = 10)
plt.ylabel('Shear stress (MPa)', fontsize = 10)
plt.legend(frameon=False, fontsize = 9)
plt.tight_layout()
plt.savefig('C:/Users/daizh/manuscript_shear_structure_formation_different_conditions/python_file/notebook_plot/general_discription_shear_velocity.svg', dpi=600, format='svg')
# path_ShearVelocity_ = ['p01mps', 'p05mps', 'p1mps', 'p5mps', '1mps']

plt.show()

# %%
fig = plt.figure(figsize=(2.4,2.4*3))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

# set height ratios for subplots
# set layout
gs = gridspec.GridSpec(3, 1, height_ratios=[1, 1, 1]) 
ax2 = plt.subplot(gs[2])
ax2s=ax2.twinx()  
ax1 = plt.subplot(gs[1], sharex = ax2)
ax1s=ax1.twinx()  
ax0 = plt.subplot(gs[0], sharex = ax2)
ax0s=ax0.twinx()  
ax0.label_outer()
ax1.label_outer()
plt.subplots_adjust(hspace=.0)
# set color
ax0s.spines['right'].set_color('r')
ax0s.tick_params(axis='y', colors='red')
ax1s.spines['right'].set_color('r')
ax1s.tick_params(axis='y', colors='red')
ax2s.spines['right'].set_color('r')
ax2s.tick_params(axis='y', colors='red')
# plot respectively
ax0.plot(HistoryData_1mps_[:, 1] * 1000,  \
         HistoryData_1mps_[:, 4]/10**6,\
         linewidth = 1, color = 'k', )
ax0.set_xlim([3.3, 3.6])
ax0.set_xticks([3.3, 3.4, 3.5, 3.6])
ax0.set_ylim(4, 6.5)
ax0.set_yticks([4.5, 5.0, 5.5, 6.0])
ax1.plot(HistoryData_20MPa_[:, 1] * 1000,  \
         HistoryData_20MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'darkorange', )
ax1.set_ylim(4.0, 6.5)
ax1.set_yticks([4.5, 5.0, 5.5, 6.0])
ax2.plot(HistoryData_p01mps_[:, 1] * 1000,  \
         HistoryData_p01mps_[:, 4]/10**6,\
         linewidth = 1, color = 'g', )
ax2.set_ylim(4, 6.5)
ax2.set_yticks([4.5, 5.0, 5.5, 6.0])

ax0s.plot(HistoryData_1mps_[:, 1] * 1000,  \
         np.abs((HistoryData_1mps_[:, 8] - HistoryData_1mps_[:, 10]) / 2),\
         linewidth = 1, color = 'r', )
ax0s.set_ylim(-0.5, 2.5)
ax0s.set_yticks([0, 0.5, 1.0, 1.5, 2, 2.5])
ax1s.plot(HistoryData_20MPa_[:, 1] * 1000,  \
         np.abs((HistoryData_20MPa_[:, 8] - HistoryData_20MPa_[:, 10]) / 2),\
         linewidth = 1, color = 'r', )
ax1s.set_ylim(-0.5, 2.5)
ax1s.set_yticks([0, 0.5, 1.0, 1.5, 2, 2.5])
ax2s.plot(HistoryData_p01mps_[:, 1] * 1000,  \
         np.abs((HistoryData_p01mps_[:, 8] - HistoryData_p01mps_[:, 10]) / 2),\
         linewidth = 1, color = 'r', )
ax2s.set_ylim(-0.5, 2.5)
ax2s.set_yticks([0, 0.5, 1.0, 1.5, 2, 2.5])
# set labels
ax2.set_xlabel('Displacement (mm)', fontsize = 10)
ax0.set_ylabel('Shear stress (MPa)', fontsize = 10)
ax1.set_ylabel('Shear stress (MPa)', fontsize = 10)
ax2.set_ylabel('Shear stress (MPa)', fontsize = 10)
ax0s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax1s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax2s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax0.get_xaxis().set_visible(False)
ax1.get_xaxis().set_visible(False)
ax0.spines['bottom'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax0s.spines['bottom'].set_visible(False)
ax1s.spines['top'].set_visible(False)
ax1s.spines['bottom'].set_visible(False)
ax2s.spines['top'].set_visible(False)

#  save figure

plt.savefig('C:/Users/daizh/manuscript_shear_structure_formation_different_conditions/python_file/notebook_plot/general_discription_shear_velocity_inset.svg', dpi=600, format='svg')
plt.show()

# %%
#%% read FrictionState and HistoryData (load stiffness)
# table head: 0. Load pointer displacement, 1. Friction, 2. Top plate displacement, 
# 3. Bottom plate displacement, 4. Top plate velocity, 5. Bottom plate velocity
FrictionState_1k_ = read_FrictionState(os.path.join(path_Conditions_[2], path_LoadStiffness_[0], path_FrictionState_))
FrictionState_2k_ = read_FrictionState(os.path.join(path_Conditions_[2], path_LoadStiffness_[1], path_FrictionState_))
FrictionState_4k_ = read_FrictionState(os.path.join(path_Conditions_[2], path_LoadStiffness_[2], path_FrictionState_))
FrictionState_20k_ = read_FrictionState(os.path.join(path_Conditions_[2], path_LoadStiffness_[3], path_FrictionState_))
FrictionState_80k_ = read_FrictionState(os.path.join(path_Conditions_[2], path_LoadStiffness_[4], path_FrictionState_))

# table head: 0. step, 1. displacement, 2. gouge_thickness, 3. shear_strain,
# 4. shear_stress, 5. normal_stress, 6. friction,  7. plate_displacement,
# 8. plate_velocity, 9. plate_displacement_bottom, 10. plate_velocity_bottom,
# 11. shear_strain_rate
HistoryData_1k_ = read_HistoryData(os.path.join(path_Conditions_[2], path_LoadStiffness_[0], path_HistoryData_))
HistoryData_2k_ = read_HistoryData(os.path.join(path_Conditions_[2], path_LoadStiffness_[1], path_HistoryData_))
HistoryData_4k_ = read_HistoryData(os.path.join(path_Conditions_[2], path_LoadStiffness_[2], path_HistoryData_))
HistoryData_20k_ = read_HistoryData(os.path.join(path_Conditions_[2], path_LoadStiffness_[3], path_HistoryData_))
HistoryData_80k_ = read_HistoryData(os.path.join(path_Conditions_[2], path_LoadStiffness_[4], path_HistoryData_))

t_ = HistoryData_80k_[:,4]
t_index_ = []
for i_ in np.where(t_ < 0)[0]:
    t_index_.append(np.arange(i_ - 100, i_ + 100))
t_index_ = np.array(t_index_)    
t_index_ = np.ravel(t_index_)
t_index_ = np.unique(t_index_)
t_index_ = np.delete(t_index_, np.where(t_index_ > HistoryData_80k_.shape[0] - 1))
HistoryData_80k_ = np.delete(HistoryData_80k_, t_index_, axis = 0)
# Out:
# Reading friction state...
#
# Index(['Load pointer displacement', ' Friction', ' Top plate displacement',
#        ' Bottom plate displacement', ' Top plate velocity',
#        ' Bottom plate velocity'],
#       dtype='object')
#
# Read friction state successful
#
#
# Reading friction state...
#
# Index(['Load pointer displacement', ' Friction', ' Top plate displacement',
#        ' Bottom plate displacement', ' Top plate velocity',
#        ' Bottom plate velocity'],
#       dtype='object')
#
# Read friction state successful
#
#
# Reading friction state...
#
# Index(['Load pointer displacement', ' Friction', ' Top plate displacement',
#        ' Bottom plate displacement', ' Top plate velocity',
#        ' Bottom plate velocity'],
#       dtype='object')
#
# Read friction state successful
#
#
# Reading friction state...
#
# Index(['Load pointer displacement', ' Friction', ' Top plate displacement',
#        ' Bottom plate displacement', ' Top plate velocity',
# ...

# %%
# friction overall (different load stiffness)
plt.figure(figsize=(2.4,2.4))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

plt.plot(HistoryData_80k_[:, 1] * 1000,  \
         HistoryData_80k_[:, 4]/10**6,\
         linewidth = 1, color = 'k', label = '80k$_{0}$')
plt.plot(HistoryData_20k_[:, 1] * 1000,  \
         HistoryData_20k_[:, 4]/10**6,\
         linewidth = 1, color = 'm', label = '20k$_{0}$')
plt.plot(HistoryData_4k_[:, 1] * 1000,  \
         HistoryData_4k_[:, 4]/10**6,\
         linewidth = 1, color = 'darkorange', label = '4k$_{0}$')
plt.plot(HistoryData_2k_[:, 1] * 1000,  \
         HistoryData_2k_[:, 4]/10**6,\
         linewidth = 1, color = 'b', label = '2k$_{0}$')
plt.plot(HistoryData_20MPa_[:, 1] * 1000,  \
         HistoryData_20MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'g', label = 'k$_{0}$')

plt.xlim([-0.1, 4])
plt.ylim([0, 7])
# plt.ylim([-0.5, 15])
plt.xlabel('Displacement (mm)', fontsize = 10)
plt.ylabel('Shear stress (MPa)', fontsize = 10)
plt.legend(frameon=False, fontsize = 9)
# plt.tight_layout()
plt.savefig('C:/Users/daizh/manuscript_shear_structure_formation_different_conditions/python_file/notebook_plot/general_discription_load_stiffness.svg', dpi=600, format='svg')
plt.show()

# %%
fig = plt.figure(figsize=(2.4,2.4*3))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

# set height ratios for subplots
# set layout
gs = gridspec.GridSpec(3, 1, height_ratios=[1, 1, 1]) 
ax2 = plt.subplot(gs[2])
ax2s=ax2.twinx()  
ax1 = plt.subplot(gs[1], sharex = ax2)
ax1s=ax1.twinx()  
ax0 = plt.subplot(gs[0], sharex = ax2)
ax0s=ax0.twinx()  
ax0.label_outer()
ax1.label_outer()
plt.subplots_adjust(hspace=.0)
# set color
ax0s.spines['right'].set_color('r')
ax0s.tick_params(axis='y', colors='red')
ax1s.spines['right'].set_color('r')
ax1s.tick_params(axis='y', colors='red')
ax2s.spines['right'].set_color('r')
ax2s.tick_params(axis='y', colors='red')
# plot respectively
ax0.plot(HistoryData_80k_[:, 1] * 1000,  \
         HistoryData_80k_[:, 4]/10**6,\
         linewidth = 1, color = 'k', )
ax0.set_xlim([3.3, 3.6])
ax0.set_xticks([3.3, 3.4, 3.5, 3.6])
ax0.set_ylim(4, 6.5)
ax0.set_yticks([4.5, 5.0, 5.5, 6.0])
ax1.plot(HistoryData_4k_[:, 1] * 1000,  \
         HistoryData_4k_[:, 4]/10**6,\
         linewidth = 1, color = 'darkorange', )
ax1.set_ylim(4.0, 6.5)
ax1.set_yticks([4.5, 5.0, 5.5, 6.0])
ax2.plot(HistoryData_20MPa_[:, 1] * 1000,  \
         HistoryData_20MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'g', )
ax2.set_ylim(4, 6.5)
ax2.set_yticks([4.5, 5.0, 5.5, 6.0])

ax0s.plot(HistoryData_80k_[:, 1] * 1000,  \
         np.abs((HistoryData_80k_[:, 8] - HistoryData_80k_[:, 10]) / 2),\
         linewidth = 1, color = 'r', )
ax0s.set_ylim(-0.5, 2.5)
ax0s.set_yticks([0, 0.5, 1.0, 1.5, 2, 2.5])
ax1s.plot(HistoryData_4k_[:, 1] * 1000,  \
         np.abs((HistoryData_4k_[:, 8] - HistoryData_4k_[:, 10]) / 2),\
         linewidth = 1, color = 'r', )
ax1s.set_ylim(-0.5, 2.5)
ax1s.set_yticks([0, 0.5, 1.0, 1.5, 2, 2.5])
ax2s.plot(HistoryData_20MPa_[:, 1] * 1000,  \
         np.abs((HistoryData_20MPa_[:, 8] - HistoryData_20MPa_[:, 10]) / 2),\
         linewidth = 1, color = 'r', )
ax2s.set_ylim(-0.5, 2.5)
ax2s.set_yticks([0, 0.5, 1.0, 1.5, 2, 2.5])
# set labels
ax2.set_xlabel('Displacement (mm)', fontsize = 10)
ax0.set_ylabel('Shear stress (MPa)', fontsize = 10)
ax1.set_ylabel('Shear stress (MPa)', fontsize = 10)
ax2.set_ylabel('Shear stress (MPa)', fontsize = 10)
ax0s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax1s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax2s.set_ylabel('$\mathit{v}$$_\mathrm{p}$ (m/s)', fontsize = 10, color = 'r')
ax0.get_xaxis().set_visible(False)
ax1.get_xaxis().set_visible(False)
ax0.spines['bottom'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax0s.spines['bottom'].set_visible(False)
ax1s.spines['top'].set_visible(False)
ax1s.spines['bottom'].set_visible(False)
ax2s.spines['top'].set_visible(False)

#  save figure

plt.savefig('C:/Users/daizh/manuscript_shear_structure_formation_different_conditions/python_file/notebook_plot/general_discription_load_stiffness_inset.svg', dpi=600, format='svg')
plt.show()

# %%
fig = plt.figure(figsize=(2.4,2.4*3))
plt.rcParams['font.size'] = 9
plt.rc('font', family = 'Arial')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'

# set height ratios for subplots
# set layout
gs = gridspec.GridSpec(3, 1, height_ratios=[1, 1, 1]) 
ax2 = plt.subplot(gs[2])
ax2s=ax2.twinx()  
ax1 = plt.subplot(gs[1], sharex = ax2)
ax1s=ax1.twinx()  
ax0 = plt.subplot(gs[0], sharex = ax2)
ax0s=ax0.twinx()  
ax0.label_outer()
ax1.label_outer()
plt.subplots_adjust(hspace=.0)
# set color
ax0s.spines['right'].set_color('r')
ax0s.tick_params(axis='y', colors='red')
ax1s.spines['right'].set_color('r')
ax1s.tick_params(axis='y', colors='red')
ax2s.spines['right'].set_color('r')
ax2s.tick_params(axis='y', colors='red')
# plot respectively
ax0.plot(HistoryData_40MPa_[:, 1] * 1000,  \
         HistoryData_40MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'k', )
ax0.set_xlim([3.3, 3.6])
ax0.set_xticks([3.3, 3.4, 3.5, 3.6])
ax0.set_ylim(9.5, 11.5)
ax0.set_yticks([10.0, 10.5, 11.0, 11.5])
ax1.plot(HistoryData_20MPa_[:, 1] * 1000,  \
         HistoryData_20MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'darkorange', )
ax1.set_ylim(4.0, 6.5)
ax1.set_yticks([4.5, 5.0, 5.5, 6.0])
ax2.plot(HistoryData_1MPa_[:, 1] * 1000,  \
         HistoryData_1MPa_[:, 4]/10**6,\
         linewidth = 1, color = 'g', )
ax2.set_ylim(0.2, 0.4)
ax2.set_yticks([0.25, 0.30, 0.35])

ax0s.plot(HistoryData_10MPa_[:, 1] * 1000,  \
         np.abs((HistoryData_10MPa_[:, 8] - HistoryData_10MPa_[:, 10]) / 2),\
         linewidth = 1, color = 'r', )
ax0s.set_ylim(-0.5, 2.5)
ax0s.set_yticks([0, 0.5, 1.0, 1.5, 2, 2.5])
ax1s.plot(HistoryData_20MPa_[:, 1] * 1000,  \
         np.abs((HistoryData_20MPa_[:, 8] - HistoryData_20MPa_[:, 10]) / 2),\
         linewidth = 1, color = 'r', )
ax1s.set_ylim(-0.5, 2.5)
ax1s.set_yticks([0, 0.5, 1.0, 1.5, 2, 2.5])
ax2s.plot(HistoryData_1MPa_[37500:37600, 1] * 1000,  \
         np.abs((HistoryData_1MPa_[37500:37600, 8] - HistoryData_1MPa_[37500:37600, 10]) / 2),\
         linewidth = 1, color = 'r', )
# ax2s.set_ylim(-0.5, 2.5)
# ax2s.set_yticks([0, 0.5, 1.0, 1.5, 2, 2.5])
# set labels
ax2.set_xlabel('Displacement (mm)', fontsize = 10)
ax0.set_ylabel('Shear stress (MPa)', fontsize = 10)
ax1.set_ylabel('Shear stress (MPa)', fontsize = 10)
ax2.set_ylabel('Shear stress (MPa)', fontsize = 10)
ax0s.set_ylabel('Plate velocity (m/s)', fontsize = 10, color = 'r')
ax1s.set_ylabel('Plate velocity (m/s)', fontsize = 10, color = 'r')
ax2s.set_ylabel('Plate velocity (m/s)', fontsize = 10, color = 'r')
ax0.get_xaxis().set_visible(False)
ax1.get_xaxis().set_visible(False)
ax0.spines['bottom'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax0s.spines['bottom'].set_visible(False)
ax1s.spines['top'].set_visible(False)
ax1s.spines['bottom'].set_visible(False)
ax2s.spines['top'].set_visible(False)

#  save figure

# plt.savefig('C:/Users/daizh/manuscript_shear_structure_formation_different_conditions/python_file/notebook_plot/general_discription_normal_stress_inset.svg', dpi=600, format='svg')
plt.show()
